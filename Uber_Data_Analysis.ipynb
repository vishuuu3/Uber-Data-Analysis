# %% [markdown]
# ![Uber-registration-taking-place-shutterstock_665366791.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Uber Data Analysis With Python**

# %% [markdown]
# **Uber Technologies, Inc.**, commonly known as **Uber**, is an American technology company. Its services include ride-hailing, food delivery, package delivery, couriers, freight transportation, and, through a partnership with Lime, electric bicycle and motorized scooter rental.
#
# We will main use data regarding **Uber ride**
#
# Python is used to:
#
#
# * Check how long do people travel with Uber?
# * What Hour Do Most People Take Uber To Their Destination?
# * Check The Purpose Of Trips
# * Which Day Has The Highest Number Of Trips
# * What Are The Number Of Trips Per Each Day?
# * What Are The Trips In The Month
# * The starting points of trips. Where Do People Start Boarding Their Trip From Most?

# %% [markdown]
# The dataset for this project is loaded at the resource session of this course.

# %% [markdown]
# <br>
#
# ##**Import The Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

# %%
data=pd.read_csv('/content/Uber Drives - .csv')
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['MILES*'].plot(kind='hist', bins=20, title='MILES*')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('START_DATE*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('END_DATE*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('STOP*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('PURPOSE*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='index', y='MILES*', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('START_DATE*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='START_DATE*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('END_DATE*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='END_DATE*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('STOP*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='STOP*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PURPOSE*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PURPOSE*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('MILES*')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['MILES*'].plot(kind='line', figsize=(8, 4), title='MILES*')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['END_DATE*'].value_counts()
#     for x_label, grp in _df_13.groupby('START_DATE*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('START_DATE*')
# _ = plt.ylabel('END_DATE*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['STOP*'].value_counts()
#     for x_label, grp in _df_14.groupby('END_DATE*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('END_DATE*')
# _ = plt.ylabel('STOP*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['PURPOSE*'].value_counts()
#     for x_label, grp in _df_15.groupby('STOP*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('STOP*')
# _ = plt.ylabel('PURPOSE*')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_16['START_DATE*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_16, x='index', y='START_DATE*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['END_DATE*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='END_DATE*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['STOP*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='index', y='STOP*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['PURPOSE*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='index', y='PURPOSE*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ##Check for Mising Values
#
# If a data is not available, Python uses **NaN** to represnet it.
#
# Let's check below if there data points missing in our dataset.

# %%
data.isnull().any()
# Out:
# START_DATE*    False
# END_DATE*       True
# CATEGORY*       True
# START*          True
# STOP*           True
# MILES*         False
# PURPOSE*        True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %% [markdown]
# Now we can see that there are not missing values in the dataset.

# %%
data['START_DATE*'] = pd.to_datetime(data['START_DATE*'], format="%m/%d/%Y %H:%M")
data['END_DATE*'] = pd.to_datetime(data['END_DATE*'], format="%m/%d/%Y %H:%M")

# %%
hour=[]
day=[]
dayofweek=[]
month=[]
weekday=[]
for x in data['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
data['HOUR']=hour
data['DAY']=day
data['DAY_OF_WEEK']=dayofweek
data['MONTH']=month
data['WEEKDAY']=weekday

# %%
data.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21['MILES*'].plot(kind='hist', bins=20, title='MILES*')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_22['HOUR'].plot(kind='hist', bins=20, title='HOUR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_23['DAY'].plot(kind='hist', bins=20, title='DAY')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_24.groupby('START*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_25.groupby('STOP*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_26.groupby('PURPOSE*').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_27.groupby('WEEKDAY').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_28.plot(kind='scatter', x='index', y='MILES*', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29.plot(kind='scatter', x='MILES*', y='HOUR', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_30.plot(kind='scatter', x='HOUR', y='DAY', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_31.plot(kind='scatter', x='DAY', y='DAY_OF_WEEK', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['START_DATE*']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_32.sort_values('START_DATE*', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('START*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='START*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('START_DATE*')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['START_DATE*']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_33.sort_values('START_DATE*', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('STOP*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='STOP*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('START_DATE*')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['START_DATE*']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_34.sort_values('START_DATE*', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('PURPOSE*')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='PURPOSE*', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('START_DATE*')
# _ = plt.ylabel('MILES*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['START_DATE*']
#   ys = series['MILES*']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_35.sort_values('START_DATE*', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('WEEKDAY')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='WEEKDAY', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('START_DATE*')
# _ = plt.ylabel('MILES*')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['MILES*'].plot(kind='line', figsize=(8, 4), title='MILES*')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['HOUR'].plot(kind='line', figsize=(8, 4), title='HOUR')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['DAY'].plot(kind='line', figsize=(8, 4), title='DAY')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['STOP*'].value_counts()
#     for x_label, grp in _df_40.groupby('START*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('START*')
# _ = plt.ylabel('STOP*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['PURPOSE*'].value_counts()
#     for x_label, grp in _df_41.groupby('STOP*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('STOP*')
# _ = plt.ylabel('PURPOSE*')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['WEEKDAY'].value_counts()
#     for x_label, grp in _df_42.groupby('PURPOSE*')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('PURPOSE*')
# _ = plt.ylabel('WEEKDAY')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_43['START*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_43, x='index', y='START*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_44['STOP*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_44, x='index', y='STOP*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_45['PURPOSE*'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_45, x='index', y='PURPOSE*', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_46['WEEKDAY'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_46, x='index', y='WEEKDAY', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ##**Categories We Have**

# %%
data['CATEGORY*'].value_counts()
# Out:
# CATEGORY*
# Business    647
# Personal      6
# Name: count, dtype: int64

# %%
sns.countplot(x='CATEGORY*',data=data)
# Out:
# <Axes: xlabel='CATEGORY*', ylabel='count'>

# %% [markdown]
# We have large number of business rides caegory as against very few personal rides.

# %% [markdown]
# ##**How long do people travel with Uber?**

# %%
data['MILES*'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# mostly people travel in a short mile with Uber.

# %% [markdown]
# ##**What Hour Do Most People Take Uber To Their Destination?**

# %%
hours = data['START_DATE*'].dt.hour.value_counts()
hours.plot(kind='bar',color='red',figsize=(10,5))
plt.xlabel('Hours')
plt.ylabel('Frequency')
plt.title('Number of trips Vs hours')
# Out:
# Text(0.5, 1.0, 'Number of trips Vs hours')

# %% [markdown]
# As we can see most people take Uber to their destination around the 13th hour(1pm) and the least hour is 2 am.

# %% [markdown]
# #**Check The Purpose Of Trips**

# %%
data['PURPOSE*'].value_counts().plot(kind='bar',figsize=(10,5),color='brown')
# Out:
# <Axes: xlabel='PURPOSE*'>

# %% [markdown]
# We can notice that mostly the purpose of the trip is meeting and meal/entertain.

# %% [markdown]
# ##**Which Day Has The Highest Number Of Trips**

# %%
data['WEEKDAY'].value_counts().plot(kind='bar',figsize=(10,5),color='blue')
# Out:
# <Axes: xlabel='WEEKDAY'>

# %% [markdown]
# So Friday has the highest number of Trips.

# %% [markdown]
# ##**What Are The Number Of Trips Per Each Day?**

# %%
data['DAY'].value_counts().plot(kind='bar',figsize=(10,5),color='green')
# Out:
# <Axes: xlabel='DAY'>

# %% [markdown]
# ##**What Are The Trips In The Month**

# %%
data['MONTH'].value_counts().plot(kind='bar',figsize=(10,5),color='black')
# Out:
# <Axes: xlabel='MONTH'>

# %% [markdown]
# We can see that December(12) has the most trips.

# %% [markdown]
# ##**The starting points of trips. Where Do People Start Boarding Their Trip From Most?**

# %%
data['START*'].value_counts().plot(kind='bar',figsize=(25,10),color='blue')
# Out:
# <Axes: xlabel='START*'>

# %% [markdown]
# Most people in this dataset starts their journey from **Cary** followed by some unknown location and then Morrisville.
